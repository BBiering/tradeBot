# %% [markdown]
# # Project: Win 100 points on the Dax

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime
import plotly.graph_objects as go

# %load_ext autoreload
# %autoreload 2

# %%
dax_symbol = '^GDAXI'

# %%
dax = yf.Ticker(dax_symbol)

# %%
hist = dax.history(period="max")

# %%
df_dax = hist.loc[hist.index >= '2020-01-01']

# %%
df_dax
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2020-01-02  13233.709961  13425.030273  13225.160156  13385.929688   75341400
# 2020-01-03  13266.389648  13282.740234  13120.719727  13219.139648   80793400
# 2020-01-06  13085.490234  13143.110352  12948.169922  13126.990234   71778600
# 2020-01-07  13199.589844  13283.879883  13166.400391  13226.830078   78282300
# 2020-01-08  13140.490234  13334.040039  13106.269531  13320.179688   88178800
# ...                  ...           ...           ...           ...        ...
# 2022-03-11  13479.690430  13943.969727  13407.969727  13628.110352  130836100
# 2022-03-14  13827.219727  14082.059570  13815.799805  13929.110352  118949300
# 2022-03-15  13768.440430  13974.839844  13577.809570  13917.269531  101279000
# 2022-03-16  14245.769531  14553.099609  14183.259766  14440.740234  138610100
# 2022-03-17  14500.049805  14509.230469  14243.940430  14388.059570          0
#
#             Dividends  Stock Splits
# Date
# 2020-01-02          0             0
# 2020-01-03          0             0
# 2020-01-06          0             0
# 2020-01-07          0             0
# 2020-01-08          0             0
# ...               ...           ...
# 2022-03-11          0             0
# 2022-03-14          0             0
# 2022-03-15          0             0
# 2022-03-16          0             0
# 2022-03-17          0             0
#
# [563 rows x 7 columns]

# %%
fig = go.Figure(data=[go.Candlestick(x=df_dax.index,
                                     open=df_dax.Open,
                                     high=df_dax.High,
                                     low=df_dax.Low,
                                     close=df_dax.Close)])

fig.show()

# %%
13000*0.01
# Out:
# 130.0
